-- %% [markdown]
-- #Build Driver Standings (Construir Classificação de Pilotos)
--
-- ##Sources (Fontes)
-- - fact_session_results
-- - dim_drivers
--
-- ##Output Columns (Colunas de Saída)
--
-- - 1.season (temporada)
-- - 2.driver id (id do piloto)
-- - 3.driver name (nome do piloto)
-- - 4.nationality (nacionalidade)
-- - 5.race starts (largadas em corridas)
-- - 6.total points (pontos totais)
-- - 7.number of wins (número de vitórias)
-- - 8.number of podiums (número de pódios)
-- - 9.standing position (posição na classificação)

-- %%
CREATE OR REPLACE VIEW formula1.gold.v_driver_standing 
AS
WITH driver_session_summary
AS
(SELECT r.season,
    d.driver_id,
    d.driver_name,
    d.nationality,
    COUNT(*) AS race_starts,
    SUM(r.points) AS total_points,
    COUNT_IF(r.is_win) AS number_of_wins,
    COUNT_IF(r.is_podium) AS number_of_podiums

FROM formula1.gold.fact_session_results r
JOIN formula1.gold.dim_drivers d
    ON r.driver_id = d.driver_id
    GROUP BY r.season,
            d.driver_id,
            d.driver_name,
            d.nationality)

SELECT season,
    driver_id,
    driver_name,
    nationality,
    RANK() OVER (PARTITION BY season ORDER BY total_points DESC, number_of_wins DESC) AS standing,
    race_starts,
    total_points,
    number_of_wins,
    number_of_podiums
FROM driver_session_summary;

-- %%
SELECT * FROM formula1.gold.v_driver_standing WHERE season = 2025
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>season</th><th>driver_id</th><th>driver_name</th><th>nationality</th><th>standing</th><th>race_starts</th><th>total_points</th><th>number_of_wins</th><th>number_of_podiums</th></tr></thead><tbody><tr><td>2025</td><td>norris</td><td>Lando Norris</td><td>British</td><td>1</td><td>30</td><td>423.0</td><td>9</td><td>22</td></tr><tr><td>2025</td><td>max_verstappen</td><td>Max Verstappen</td><td>Dutch</td><td>2</td><td>30</td><td>421.0</td><td>10</td><td>18</td></tr><tr><td>2025</td><td>piastri</td><td>Oscar Piastri</td><td>Australian</td><td>3</td><td>30</td><td>410.0</td><td>8</td><td>20</td></tr><tr><td>2025</td><td>russell</td><td>George Russell</td><td>British</td><td>4</td><td>30</td><td>319.0</td><td>2</td><td>12</td></tr><tr><td>2025</td><td>leclerc</td><td>Charles Leclerc</td><td>Monegasque</td><td>5</td><td>30</td><td>242.0</td><td>0</td><td>7</td></tr><tr><td>2025</td><td>hamilton</td><td>Lewis Hamilton</td><td>British</td><td>6