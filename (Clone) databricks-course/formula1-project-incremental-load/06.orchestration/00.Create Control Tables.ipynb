-- %%
%run ../00-common/01.environment-config

-- %%
%python
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog_name}.{control_schema}")
-- Out:
-- DataFrame[]

-- %%
%python
spark.sql(f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.{control_schema}.batch_control
    (
        batch_id STRING,
        status STRING,
        created_timestamp TIMESTAMP,
        updated_timestamp TIMESTAMP
    )
""")
-- Out:
-- DataFrame[]

-- %%
SELECT * FROM formula1_incr.control.batch_control
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>batch_id</th><th>status</th><th>created_timestamp</th><th>updated_timestamp</th></tr></thead><tbody><tr><td>2025-01</td><td>in_progress</td><td>2026-09-14T13:57:58.598Z</td><td>2026-09-14T13:57:58.598Z</td></tr></tbody></table></div>

-- %%
DELETE FROM formula1_incr.control.batch_control;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>
